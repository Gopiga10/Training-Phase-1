# %%
deliveries_df = spark.read.option("header", True).csv("/FileStore/tables/deliveries.csv")
selected_columns_df = deliveries_df.select("batter", "bowler", "total_runs")
print("Using show():")
selected_columns_df.show(5)
print("Using display():")
display(selected_columns_df)
# Out:
# Using show():
# +-----------+-------+----------+
# |     batter| bowler|total_runs|
# +-----------+-------+----------+
# | SC Ganguly|P Kumar|         1|
# |BB McCullum|P Kumar|         0|
# |BB McCullum|P Kumar|         1|
# |BB McCullum|P Kumar|         0|
# |BB McCullum|P Kumar|         0|
# +-----------+-------+----------+
# only showing top 5 rows
#
# Using display():
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
